# %%
import torch
import numpy as np

# %%
data = [[1,2], [3,4]]
x = torch.tensor(data)
print(x)
# Out:
# tensor([[1, 2],
#         [3, 4]])

# %%
print("Tensor:", x)
print("Shape:", x.shape)
print("Data type:", x.dtype)
# Out:
# Tensor: tensor([[1, 2],
#         [3, 4]])
# Shape: torch.Size([2, 2])
# Data type: torch.int64

# %%
y = torch.tensor([
    [1,2,3],
    [4,5,6]
])

# %%
print(y)
print("shape:", y.shape)
# Out:
# tensor([[1, 2, 3],
#         [4, 5, 6]])
# shape: torch.Size([2, 3])

# %%
# random tensor

z = torch.rand(2,3)
print(z)
# Out:
# tensor([[0.8567, 0.9004, 0.4943],
#         [0.0596, 0.6861, 0.0850]])

# %%
# using numpy

arr = np.array([10,20,30])
a = torch.from_numpy(arr)
print(arr)
print(a)
# Out:
# [10 20 30]
# tensor([10, 20, 30])

# %%
print(a.device)
# Out:
# cpu
